# %% [markdown]
# ## FHIR for Research Workshop - Exercise 2
#
# ## Learning Objectives and Key Concepts
#
# In this exercise, you will:
#
# - Apply Knowledge from previous exercises
# - Understand dbGaP extensions to ResearchStudy
# - Query for dbGaP asthma studies by title
# - Query for dbGaP studies by codes
#
# ## Identify dbGaP Asthma datasets
# For this exercise we will search for studies/datasets in dbGaP related to asthma.
#
# ## Motivation/Purpose
# To identify asthma studies from which data may be aggregated. Consent codes will be listed to see if the data from different studies may be used for a particular research purpose
#
#  ### Icons in this Guide
#  📘 A link to a useful external reference related to the section the icon appears in
#
#  🖐 A hands-on section where you will code something or interact with the server
#
#
# Acknowledging use of code snippets from [NIH FHIR training](https://github.com/NIH-ODSS/fhir-exercises/tree/main/Python) Exercise 0.
#
# ## Step 1:  Set up a FHIR Client
#
# Obtain our NCBI API Key and set up a client to make requests, handle pagination etc.

# %%
import json
import os
from dbgapfhir import dbgapfhir
import pandas as pd

FHIR_SERVER = 'https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1'
API_KEY_PATH = '~/.keys/ncbi_api_key.txt'

with open(os.path.expanduser(API_KEY_PATH)) as f:  
    api_key = f.read()
    
mf = dbgapfhir(FHIR_SERVER, api_key=api_key)

# %% [markdown]
# ## Step 2:  Explore ResearchStudy resource with dbGaP extensions
#
# To help understand what a Research Study resource looks like in dbGaP on FHIR we'll run the following query for a single study and list the whole resource. 'Resource' is a generic term for the real world entities that FHIR can represent. For this query the resource is a ResearchStudy.
#
# This helps see that some of the data we want to extract from the resource are held in extensions to the FHIR model.

# %%
documents = mf.run_query("ResearchStudy?_id=phs001156")
print("# of studies:{}".format(len(documents)))

for s in documents:

    print ("Study id: {}".format(s['id']))
    print ("Study title: {}".format(s['title']))
    print ("Full resource")
    print(json.dumps(s, indent=3))
    print('_'*40)
# Out:
# Total  Resources: 1
# Total  Bytes: 9383
# Time elapsed 0.1386 seconds
# # of studies:1
# Study id: phs001156
# Study title: The EVE Asthma Genetics Consortium: Building Upon GWAS
# Full resource
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs001156",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-02-14T01:59:54.353-05:00",
#       "source": "#LLcpbzxw95eFPBGW",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs001156.v2.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2018-05-08"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs001156.v2.p1 - 1",
#                   "display": "GRU-NPU"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumPhenotypeDatasets",
#                "valueCount": {
#                   "value": 4,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumVariables",
#                "valueCount": {
#                   "value": 19,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumAnalyses",
#                "valueCount": {
#                   "value": 4,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "value": 296,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSamples",
#                "valueCount": {
#                   "value": 296,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs001156.v2.p1"
#       }
#    ],
#    "title": "The EVE Asthma Genetics Consortium: Building Upon GWAS",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case-Control",
#                "display": "Case-Control"
#             }
#          ],
#          "text": "Case-Control"
#       }
#    ],
#    "focus": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "description": "\nThe EVE Asthma Genetics Consortium comprises U.S. investigators who have conducted genome-wide association studies (GWAS) of asthma; the main objective is to combine results of individual studies to increase the overall power to identify loci for asthma and asthma-associated traits. The consortium includes investigators at 9 U.S. institutions with GWAS results for &gt;10,000 individuals representing European American, African American, African Caribbean, U.S. Hispanic, and Mexican populations and includes the following studies:  - The Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE) - The Genetic Research on Asthma in the African Diaspora (GRAAD) Study - The Genetics of Asthma in Latino Americans (GALA 1) Study - The Childhood Asthma Management Program (CAMP) - The Childhood Asthma Research and Education (CARE) Network - The Children&#39;s Health Study (CHS) - Mexico City Childhood Asthma Study (MCCAS) - The Chicago Asthma Genetics Study (CAG)* - The National Heart, Lung, and Blood Institute Collaborative Studies of the Genetics of Asthma (CSGA)* - The Severe Asthma Research Program (SARP)*  (*CAG, CSGA, and SARP are part of the NHLBI-supported SNP Typing for Association with Multiple Phenotypes from Existing Epidemiologic Data (STAMPEED) consortium.) \n\nFor the GWAS, we developed a common set of &gt;1 million genotyped and imputed SNPs from the EVE Asthma Genetics Consortium to be tested for association with asthma and associated phenotypes in all samples and combined p-values for a grand meta-analysis for asthma gene discovery. A subset of 296 individuals representing African American, European American, and Latino ancestry were selected for whole genome sequencing.\n\nThe broad goals of this project were to characterize the genetic architecture of asthma and associated quantitative phenotypes (e.g., lung function, total serum IgE) in ethnically diverse populations from the U.S., Mexico, Puerto Rico, and Barbados.\n",
#    "enrollment": [
#       {
#          "reference": "Group/phs001156.v2.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHLBI",
#       "type": "Organization",
#       "display": "National Heart, Lung, and Blood Institute"
#    }
# }
# ________________________________________

# %% [markdown]
# Note that extensions include
#
# - A link to the study description e.g. https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs001156.v2.p1
# - Study release date
# - List groups of subjects within the study for which the subjects consented to spexcific uses of their data
# - Summary counts of various kinds - subjects, samples, variables, etc.

# %% [markdown]
# ### Query for a different study

# %%
documents = mf.run_query("ResearchStudy?_id=phs001222")
print("# of studies:{}".format(len(documents)))

for s in documents:

    print ("Study id: {}".format(s['id']))
    print ("Study title: {}".format(s['title']))
    print ("Full resource")
    print(json.dumps(s, indent=3))
    print('_'*40)
# Out:
# Total  Resources: 1
# Total  Bytes: 31231
# Time elapsed 0.1762 seconds
# # of studies:1
# Study id: phs001222
# Study title: CCDG - Whole Genome Sequencing in Type 1 Diabetes (T1DGC)
# Full resource
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs001222",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-02-14T01:58:59.250-05:00",
#       "source": "#YQ5VqwQ7veThKjIm",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs001222.v1.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2020-06-25"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs001222.v1.p1 - 1",
#                   "display": "DS-DRC-IRB-NPU"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumPhenotypeDatasets",
#                "valueCount": {
#                   "value": 4,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "value": 1,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumVariables",
#                "valueCount": {
#                   "value": 13,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "value": 1414,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSamples",
#                "valueCount": {
#                   "value": 1414,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "EUR"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 17,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "AFO"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 46,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "AFA"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 1200,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "LAC"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 47,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "LEN"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 95,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "OTR"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 9,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                         "code": "Unknown"
#                      }
#                   ]
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                         "code": "WGS_markerset_grc38"
#                      }
#                   ]
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                         "code": "SNP Genotypes (NGS)"
#                      }
#                   ]
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                         "code": "CNV (NGS)"
#                      }
#                   ]
#                }
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs001222.v1.p1"
#       }
#    ],
#    "title": "CCDG - Whole Genome Sequencing in Type 1 Diabetes (T1DGC)",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case-Control",
#                "display": "Case-Control"
#             }
#          ],
#          "text": "Case-Control"
#       }
#    ],
#    "focus": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D003922",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D003922",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Autoimmune Diabetes",
#                "display": "Autoimmune Diabetes"
#             }
#          ],
#          "text": "Autoimmune Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Brittle Diabetes Mellitus",
#                "display": "Brittle Diabetes Mellitus"
#             }
#          ],
#          "text": "Brittle Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Brittle",
#                "display": "Diabetes Mellitus, Brittle"
#             }
#          ],
#          "text": "Diabetes Mellitus, Brittle"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Insulin Dependent",
#                "display": "Diabetes Mellitus, Insulin Dependent"
#             }
#          ],
#          "text": "Diabetes Mellitus, Insulin Dependent"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Insulin-Dependent, 1",
#                "display": "Diabetes Mellitus, Insulin-Dependent, 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Insulin-Dependent, 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Juvenile Onset",
#                "display": "Diabetes Mellitus, Juvenile Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Juvenile Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Juvenile-Onset",
#                "display": "Diabetes Mellitus, Juvenile-Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Juvenile-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Ketosis Prone",
#                "display": "Diabetes Mellitus, Ketosis Prone"
#             }
#          ],
#          "text": "Diabetes Mellitus, Ketosis Prone"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Ketosis-Prone",
#                "display": "Diabetes Mellitus, Ketosis-Prone"
#             }
#          ],
#          "text": "Diabetes Mellitus, Ketosis-Prone"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Sudden Onset",
#                "display": "Diabetes Mellitus, Sudden Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Sudden Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Sudden-Onset",
#                "display": "Diabetes Mellitus, Sudden-Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Sudden-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Type 1",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Type I",
#                "display": "Diabetes Mellitus, Type I"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type I"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Autoimmune",
#                "display": "Diabetes, Autoimmune"
#             }
#          ],
#          "text": "Diabetes, Autoimmune"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Juvenile-Onset",
#                "display": "Diabetes, Juvenile-Onset"
#             }
#          ],
#          "text": "Diabetes, Juvenile-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Type 1",
#                "display": "Diabetes, Type 1"
#             }
#          ],
#          "text": "Diabetes, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: IDDM",
#                "display": "IDDM"
#             }
#          ],
#          "text": "IDDM"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Insulin Dependent Diabetes Mellitus 1",
#                "display": "Insulin Dependent Diabetes Mellitus 1"
#             }
#          ],
#          "text": "Insulin Dependent Diabetes Mellitus 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Insulin-Dependent Diabetes Mellitus 1",
#                "display": "Insulin-Dependent Diabetes Mellitus 1"
#             }
#          ],
#          "text": "Insulin-Dependent Diabetes Mellitus 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile Onset Diabetes",
#                "display": "Juvenile Onset Diabetes"
#             }
#          ],
#          "text": "Juvenile Onset Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile-Onset Diabetes",
#                "display": "Juvenile-Onset Diabetes"
#             }
#          ],
#          "text": "Juvenile-Onset Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile-Onset Diabetes Mellitus",
#                "display": "Juvenile-Onset Diabetes Mellitus"
#             }
#          ],
#          "text": "Juvenile-Onset Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Ketosis-Prone Diabetes Mellitus",
#                "display": "Ketosis-Prone Diabetes Mellitus"
#             }
#          ],
#          "text": "Ketosis-Prone Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Sudden-Onset Diabetes Mellitus",
#                "display": "Sudden-Onset Diabetes Mellitus"
#             }
#          ],
#          "text": "Sudden-Onset Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Type 1 Diabetes",
#                "display": "Type 1 Diabetes"
#             }
#          ],
#          "text": "Type 1 Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Type 1 Diabetes Mellitus",
#                "display": "Type 1 Diabetes Mellitus"
#             }
#          ],
#          "text": "Type 1 Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0011854",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D003922",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Autoimmune Diabetes",
#                "display": "Autoimmune Diabetes"
#             }
#          ],
#          "text": "Autoimmune Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Brittle Diabetes Mellitus",
#                "display": "Brittle Diabetes Mellitus"
#             }
#          ],
#          "text": "Brittle Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Brittle",
#                "display": "Diabetes Mellitus, Brittle"
#             }
#          ],
#          "text": "Diabetes Mellitus, Brittle"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Insulin Dependent",
#                "display": "Diabetes Mellitus, Insulin Dependent"
#             }
#          ],
#          "text": "Diabetes Mellitus, Insulin Dependent"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Insulin-Dependent, 1",
#                "display": "Diabetes Mellitus, Insulin-Dependent, 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Insulin-Dependent, 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Juvenile Onset",
#                "display": "Diabetes Mellitus, Juvenile Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Juvenile Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Juvenile-Onset",
#                "display": "Diabetes Mellitus, Juvenile-Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Juvenile-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Ketosis Prone",
#                "display": "Diabetes Mellitus, Ketosis Prone"
#             }
#          ],
#          "text": "Diabetes Mellitus, Ketosis Prone"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Ketosis-Prone",
#                "display": "Diabetes Mellitus, Ketosis-Prone"
#             }
#          ],
#          "text": "Diabetes Mellitus, Ketosis-Prone"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Sudden Onset",
#                "display": "Diabetes Mellitus, Sudden Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Sudden Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Sudden-Onset",
#                "display": "Diabetes Mellitus, Sudden-Onset"
#             }
#          ],
#          "text": "Diabetes Mellitus, Sudden-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Type 1",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes Mellitus, Type I",
#                "display": "Diabetes Mellitus, Type I"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type I"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Autoimmune",
#                "display": "Diabetes, Autoimmune"
#             }
#          ],
#          "text": "Diabetes, Autoimmune"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Juvenile-Onset",
#                "display": "Diabetes, Juvenile-Onset"
#             }
#          ],
#          "text": "Diabetes, Juvenile-Onset"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Diabetes, Type 1",
#                "display": "Diabetes, Type 1"
#             }
#          ],
#          "text": "Diabetes, Type 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: IDDM",
#                "display": "IDDM"
#             }
#          ],
#          "text": "IDDM"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Insulin Dependent Diabetes Mellitus 1",
#                "display": "Insulin Dependent Diabetes Mellitus 1"
#             }
#          ],
#          "text": "Insulin Dependent Diabetes Mellitus 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Insulin-Dependent Diabetes Mellitus 1",
#                "display": "Insulin-Dependent Diabetes Mellitus 1"
#             }
#          ],
#          "text": "Insulin-Dependent Diabetes Mellitus 1"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile Onset Diabetes",
#                "display": "Juvenile Onset Diabetes"
#             }
#          ],
#          "text": "Juvenile Onset Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile-Onset Diabetes",
#                "display": "Juvenile-Onset Diabetes"
#             }
#          ],
#          "text": "Juvenile-Onset Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Juvenile-Onset Diabetes Mellitus",
#                "display": "Juvenile-Onset Diabetes Mellitus"
#             }
#          ],
#          "text": "Juvenile-Onset Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Ketosis-Prone Diabetes Mellitus",
#                "display": "Ketosis-Prone Diabetes Mellitus"
#             }
#          ],
#          "text": "Ketosis-Prone Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Sudden-Onset Diabetes Mellitus",
#                "display": "Sudden-Onset Diabetes Mellitus"
#             }
#          ],
#          "text": "Sudden-Onset Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Type 1 Diabetes",
#                "display": "Type 1 Diabetes"
#             }
#          ],
#          "text": "Type 1 Diabetes"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D003922 entry term: Type 1 Diabetes Mellitus",
#                "display": "Type 1 Diabetes Mellitus"
#             }
#          ],
#          "text": "Type 1 Diabetes Mellitus"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0011854",
#                "display": "Diabetes Mellitus, Type 1"
#             }
#          ],
#          "text": "Diabetes Mellitus, Type 1"
#       }
#    ],
#    "description": "\nThe Type 1 Diabetes Genetics Consortium (T1DGC) was established to collect resources (biological samples and data) and conduct research to better understand the genetic basis of type 1 diabetes (T1D). Collection was initiated by ascertaining affected sib-pair families (both parents, two affected siblings and, when available, an unaffected sibling), collected from five geographic regions through four recruitment networks (Asia-Pacific, Europe, North America, United Kingdom). In addition, the T1DGC collected trio families (both parents and affected child) and cases and controls from low-prevalence populations (African-American, with four grandparents self-reporting as African ancestry; Mexican-American, with four grandparents self-reporting as ancestry from Mexico). The T1DGC also served as a repository for contributed collections from other studies, all meeting the broad data-sharing policy of the T1DGC, for inclusion in the genetic studies. These collections include T1D case samples ascertained from the UK Genetic Resource Investigating Diabetes (UK GRID) cohort, SEARCH for Diabetes in Youth (SEARCH), The Genetics of Kidneys in Diabetes (GoKinD), and control samples obtained from the British 1958 Birth Cohort, the UK National Blood Services collection, CLEAR (Consortium for the Longitudinal Evaluation of African-Americans with Early Rheumatoid Arthritis), the New York Cancer Project (NYCP), and other cohorts. For the NHGRI-funded Centers for Common Disease Genomics (CCDG) project, participants with T1D and ancestry-matched controls were identified through the T1DGC, either through direct ascertainment or by contribution from other sources to the T1DGC. As the CCDG has focused initially on non-Caucasian populations for whole genome sequencing, T1DGC participants of African, Mexican and Asian ancestry (targeting ~1200 cases and ~1200 controls in each ancestral group) and a small group of participants of Northern European ancestry (~100 cases, ~100 controls) were to be contributed to the study. Whole genome sequencing of T1DGC samples would be conducted at Washington University McDonnell Genome Institute and based upon matching case-control status within an ancestry group and prioritization by the CCDG.\n",
#    "enrollment": [
#       {
#          "reference": "Group/phs001222.v1.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHGRI",
#       "type": "Organization",
#       "display": "National Human Genome Research Institute"
#    }
# }
# ________________________________________

# %% [markdown]
# ## Step 3:  Query for asthma studies
#
# With the information above we can now run our query for studies with the word asthma in the title. We rely on standard FHIR query syntax for this. According to the FHIR standard the search will be case insensitive.

# %%
documents = mf.run_query("ResearchStudy?title:contains=asthma")

print("# of studies:{}".format(len(documents)))

for s in documents:

    print ("Study id: {}".format(s['id']))
    print ("Study title: {}".format(s['title']))
# Out:
# Total  Resources: 28
# Total  Bytes: 380133
# Time elapsed 3.1350 seconds
# # of studies:28
# Study id: phs000166
# Study title: SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)
# Study id: phs000233
# Study title: Genome Wide Association Study of Asthma
# Study id: phs000355
# Study title: Genome Wide Association for Asthma and Lung Function
# Study id: phs000422
# Study title: NHLBI GO-ESP: Lung Cohorts Exome Sequencing Project (Asthma)
# Study id: phs000886
# Study title: An Omics View of Asthma through Monozygotic Twins
# Study id: phs001009
# Study title: Determinants of Asthma Following RSV Bronchiolitis in Early Life
# Study id: phs001216
# Study title: A Genome-Wide Association Study for Post-bronchodilator Lung Function in Children with Asthma
# Study id: phs001156
# Study title: The EVE Asthma Genetics Consortium: Building Upon GWAS
# Study id: phs001123
# Study title: Consortium on Asthma among African-ancestry Populations in the Americas
# Study id: phs001812
# Study title: Genetic and Epigenetic Determinants of Pediatric Obesity-Associated Asthma
# Study id: phs001180
# Study title: Genes-Environments and Admixture in Latino Asthmatics (GALA II) Study
# Study id: phs000921
# Study title: NHLBI TOPMed: Study of African Americans, Asthma, Genes and Environment (SAGE)
# Study id: phs001274
# Study title: Genes-environments and Admixture in Latino Asthmatics (GALA II) GWAS Study
# Study id: phs001143
# Study title: NHLBI TOPMed: The Genetics and Epidemiology of Asthma in Barbados
# Study id: phs002224
# Study title: Sputum RNA-Seq from Asthmatic Patients for Microbes and Genes
# Study id: phs000920
# Study title: NHLBI TOPMed - NHGRI CCDG: Genes-Environments and Admixture in Latino Asthmatics (GALA II)
# Study id: phs001726
# Study title: NHLBI TOPMed: Childhood Asthma Management Program (CAMP)
# Study id: phs000988
# Study title: NHLBI TOPMed: The Genetic Epidemiology of Asthma in Costa Rica
# Study id: phs001446
# Study title: NHLBI TOPMed: Severe Asthma Research Program (SARP)
# Study id: phs001602
# Study title: NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genetic Approaches to Gene-Air Pollution Interactions in Asthma (GAP)
# Study id: phs001603
# Study title: NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genomics and Environmental Research of Asthma (IGERA)
# Study id: phs001605
# Study title: NHLBI TOPMed: Chicago Initiative to Raise Asthma Health Equity (CHIRAH)
# Study id: phs001467
# Study title: NHLBI TOPMed: Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE)
# Study id: phs001661
# Study title: NHLBI TOPMed: Genetic Causes of Complex Pediatric Disorders - Asthma (GCPD-A)
# Study id: phs001727
# Study title: NHLBI TOPMed: Pathways to Immunologically Mediated Asthma (PIMA)
# Study id: phs001732
# Study title: NHLBI TOPMed: TReating Children to Prevent EXacerbations of Asthma (TREXA)
# Study id: phs001730
# Study title: NHLBI TOPMed: Pediatric Asthma Controller Trial (PACT)
# Study id: phs001542
# Study title: NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)

# %% [markdown]
# ## Step 4:  Extracting information about the studies
# We'll define a function for convenience. Because so many of the study details are in extensions, and there are extensions within extensions, the following function helps us deal with an extension at any level.

# %%
# for a given resource find the extension identified by a given url
# The assumption is that there is only one such extension within a given resource
# For the dbGaP ResearchStudy resource that is true
def getExtension(resource, uri):
    exts = [d for d in resource['extension'] if d['url'] == uri]
    if len(exts) > 0 :
        return exts[0]
    else:
        return None

# %% [markdown]
# We can now use the function above to find the extensions for
# * the number of subjects in the study
# * the consent groups within the study
#
# The following extracts these details and puts them into a dataframe.

# %%
def studies_to_df(documents, verbose=False):
    studies = []
    for s in documents:

        if verbose:
            print (s['id'])
            print (s['title'])
        # use our function to find the "study content" extension
        content = getExtension(s, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content")
        # use our function again to find the "number of subjects" extension nested within the content extension
        subject_ext = getExtension(content, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects")
        #print(subject_ext)
        # Handle the fact that not all studies may have this extension
        if subject_ext != None and 'value' in subject_ext['valueCount']:
            subject_count = subject_ext['valueCount']['value']
        else:
            subject_count = 0

        # Now find the extension containing the study consents
        consent_ext = getExtension(s, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents")
        # extract the display name for each consent group and print them
        if consent_ext != None:
            consents = [d['valueCoding']['display'] for d in consent_ext['extension'] ]
            if verbose:
                print(consents)
        else:
            consents = []
            
        # focus
        if 'focus' in s:
            focus = s['focus'][0]['text']
            if 'coding' in s['focus'][0]:
                focus_code = s['focus'][0]['coding'][0]['code']
            else:
                focus_code = ''
        else:
            focus = ''
            focus_code = ''
        # Add the relevant details to our list of studies
        study = {"id":s['id'], "title":s["title"], "num_subjects":subject_count,
                 "focus":focus,"focus_mesh":focus_code,"consents":consents}
        studies.append(study)
        if verbose:
            print('_'*40)
        df = pd.DataFrame(studies)
    return df

# %%
df = studies_to_df(documents)

# %% [markdown]
# ## Step 5:  Show the study data in a Dataframe
#
# We can then put our list of studies into a DataFrame for display.
#
# We're listing the consent so we can see if any of the studies could potentially be used in the Computable Cohort Representation asthma exercise.

# %%
pd.set_option('display.max_colwidth', 0)
df.sort_values(by=['id'], inplace=True)
df
# Out:
#            id  \
# 0   phs000166
# 1   phs000233
# 2   phs000355
# 3   phs000422
# 4   phs000886
# 15  phs000920
# 11  phs000921
# 17  phs000988
# 5   phs001009
# 8   phs001123
# 13  phs001143
# 7   phs001156
# 10  phs001180
# 6   phs001216
# 12  phs001274
# 18  phs001446
# 22  phs001467
# 27  phs001542
# 19  phs001602
# 20  phs001603
# 21  phs001605
# 23  phs001661
# 16  phs001726
# 24  phs001727
# 26  phs001730
# 25  phs001732
# 9   phs001812
# 14  phs002224
#
#                                                                                                                                 title  \
# 0   SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)
# 1   Genome Wide Association Study of Asthma
# 2   Genome Wide Association for Asthma and Lung Function
# 3   NHLBI GO-ESP: Lung Cohorts Exome Sequencing Project (Asthma)
# 4   An Omics View of Asthma through Monozygotic Twins
# 15  NHLBI TOPMed - NHGRI CCDG: Genes-Environments and Admixture in Latino Asthmatics (GALA II)
# 11  NHLBI TOPMed: Study of African Americans, Asthma, Genes and Environment (SAGE)
# 17  NHLBI TOPMed: The Genetic Epidemiology of Asthma in Costa Rica
# 5   Determinants of Asthma Following RSV Bronchiolitis in Early Life
# 8   Consortium on Asthma among African-ancestry Populations in the Americas
# 13  NHLBI TOPMed: The Genetics and Epidemiology of Asthma in Barbados
# 7   The EVE Asthma Genetics Consortium: Building Upon GWAS
# 10  Genes-Environments and Admixture in Latino Asthmatics (GALA II) Study
# 6   A Genome-Wide Association Study for Post-bronchodilator Lung Function in Children with Asthma
# 12  Genes-environments and Admixture in Latino Asthmatics (GALA II) GWAS Study
# 18  NHLBI TOPMed: Severe Asthma Research Program (SARP)
# 22  NHLBI TOPMed: Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE)
# 27  NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)
# 19  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genetic Approaches to Gene-Air Pollution Interactions in Asthma (GAP)
# 20  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genomics and Environmental Research of Asthma (IGERA)
# 21  NHLBI TOPMed: Chicago Initiative to Raise Asthma Health Equity (CHIRAH)
# 23  NHLBI TOPMed: Genetic Causes of Complex Pediatric Disorders - Asthma (GCPD-A)
# 16  NHLBI TOPMed: Childhood Asthma Management Program (CAMP)
# 24  NHLBI TOPMed: Pathways to Immunologically Mediated Asthma (PIMA)
# 26  NHLBI TOPMed: Pediatric Asthma Controller Trial (PACT)
# 25  NHLBI TOPMed: TReating Children to Prevent EXacerbations of Asthma (TREXA)
# 9   Genetic and Epigenetic Determinants of Pediatric Obesity-Associated Asthma
# 14  Sputum RNA-Seq from Asthmatic Patients for Microbes and Genes
#
#     num_subjects          focus focus_mesh  \
# 0   4046
# 1   0             Asthma         D001249
# 2   0             Asthma         D001249
# 3   191           Asthma         D001249
# 4   74            Asthma         D001249
# 15  4860          Lung Diseases  D008171
# 11  2106          Lung Diseases  D008171
# 17  4230          Asthma         D001249
# 5   178           Asthma         D001249
# 8   14548         Asthma         D001249
# 13  1527          Asthma         D001249
# 7   296           Asthma         D001249
# 10  4458          Lung Diseases  D008171
# 6   447           Asthma         D001249
# 12  4427          Asthma         D001249
# 18  1882          Asthma         D001249
# 22  4857          Asthma         D001249
# 27  1024          Asthma         D001249
# 19  7             Asthma         D001249
# 20  160           Asthma         D001249
# 21  292           Asthma         D001249
# 23  5464          Asthma         D001249
# 16  2640
# 24  73            Asthma         D001249
# 26  41            Asthma         D001249
# 25  89            Asthma         D001249
# 9   115           Asthma         D001249
# 14  116
#
#                                                                          consents
# 0   [NRUP, ARR]
# 1   [Analysis]
# 2   [Analysis]
# 3   [GRU]
# 4   [GRU]
# 15  [DS-LD-IRB-COL]
# 11  [DS-LD-IRB-COL]
# 17  [NRUP, DS-ASTHMA-IRB-MDS-RD]
# 5   [NRUP, DS-AAR-IRB]
# 8   [NRUP, GRU-IRB, HMB, DS-LD, HMB-IRB-NPU, DS-FDO-IRB-NPU, HMB-IRB, DS-FDO-IRB]
# 13  [NRUP, GRU-IRB]
# 7   [GRU-NPU]
# 10  [NRUP, DS-LD-IRB-COL]
# 6   [DS-ASTHMA-IRB-PUB-NPU-MDS-GSO-RD]
# 12  [DS-LD-IRB-COL]
# 18  [GRU]
# 22  [NRUP, HMB-COL]
# 27  [DS-LD-IRB-COL]
# 19  [GRU]
# 20  [GRU]
# 21  [DS-ASTHMA-IRB-COL]
# 23  [DS-ASTHMA-GSO]
# 16  [NRUP, DS-AST-COPD]
# 24  [DS-ASTHMA-IRB-COL]
# 26  [DS-ASTHMA-IRB-COL]
# 25  [DS-ASTHMA-IRB-COL]
# 9   [NRUP, GRU-IRB-COL]
# 14  [GRU]

# %% [markdown]
# ## Step 6 -  Query on focus of study, by code
#
# The MESH code for Asthma
#
# Note that this returns studies that were not retrieved where the word asthma was in the title.

# %%
documents = mf.run_query("ResearchStudy?focus=D001249")
# Out:
# Total  Resources: 25
# Total  Bytes: 332675
# Time elapsed 2.9763 seconds

# %%
studies_to_df(documents)
# Out:
#            id  \
# 0   phs001542
# 1   phs001732
# 2   phs001730
# 3   phs001729
# 4   phs001728
# 5   phs001727
# 6   phs001661
# 7   phs001467
# 8   phs001605
# 9   phs001604
# 10  phs001603
# 11  phs001602
# 12  phs001446
# 13  phs000988
# 14  phs001143
# 15  phs001274
# 16  phs001812
# 17  phs001123
# 18  phs001156
# 19  phs001216
# 20  phs001009
# 21  phs000886
# 22  phs000422
# 23  phs000355
# 24  phs000233
#
#                                                                                                                                 title  \
# 0   NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)
# 1   NHLBI TOPMed: TReating Children to Prevent EXacerbations of Asthma (TREXA)
# 2   NHLBI TOPMed: Pediatric Asthma Controller Trial (PACT)
# 3   NHLBI TOPMed: Characterizing the Response to a Leukotriene Receptor Antagonist and an Inhaled Corticosteroid (CLIC)
# 4   NHLBI TOPMed: Best ADd-on Therapy Giving Effective Response (BADGER)
# 5   NHLBI TOPMed: Pathways to Immunologically Mediated Asthma (PIMA)
# 6   NHLBI TOPMed: Genetic Causes of Complex Pediatric Disorders - Asthma (GCPD-A)
# 7   NHLBI TOPMed: Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE)
# 8   NHLBI TOPMed: Chicago Initiative to Raise Asthma Health Equity (CHIRAH)
# 9   NHLBI TOPMed: Children&#39;s Health Study (CHS) Effects of Air Pollution on the Development of Obesity in Children (Meta-AIR)
# 10  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genomics and Environmental Research of Asthma (IGERA)
# 11  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genetic Approaches to Gene-Air Pollution Interactions in Asthma (GAP)
# 12  NHLBI TOPMed: Severe Asthma Research Program (SARP)
# 13  NHLBI TOPMed: The Genetic Epidemiology of Asthma in Costa Rica
# 14  NHLBI TOPMed: The Genetics and Epidemiology of Asthma in Barbados
# 15  Genes-environments and Admixture in Latino Asthmatics (GALA II) GWAS Study
# 16  Genetic and Epigenetic Determinants of Pediatric Obesity-Associated Asthma
# 17  Consortium on Asthma among African-ancestry Populations in the Americas
# 18  The EVE Asthma Genetics Consortium: Building Upon GWAS
# 19  A Genome-Wide Association Study for Post-bronchodilator Lung Function in Children with Asthma
# 20  Determinants of Asthma Following RSV Bronchiolitis in Early Life
# 21  An Omics View of Asthma through Monozygotic Twins
# 22  NHLBI GO-ESP: Lung Cohorts Exome Sequencing Project (Asthma)
# 23  Genome Wide Association for Asthma and Lung Function
# 24  Genome Wide Association Study of Asthma
#
#     num_subjects   focus focus_mesh  \
# 0   1024          Asthma  D001249
# 1   89            Asthma  D001249
# 2   41            Asthma  D001249
# 3   19            Asthma  D001249
# 4   50            Asthma  D001249
# 5   73            Asthma  D001249
# 6   5464          Asthma  D001249
# 7   4857          Asthma  D001249
# 8   292           Asthma  D001249
# 9   56            Asthma  D001249
# 10  160           Asthma  D001249
# 11  7             Asthma  D001249
# 12  1882          Asthma  D001249
# 13  4230          Asthma  D001249
# 14  1527          Asthma  D001249
# 15  4427          Asthma  D001249
# 16  115           Asthma  D001249
# 17  14548         Asthma  D001249
# 18  296           Asthma  D001249
# 19  447           Asthma  D001249
# 20  178           Asthma  D001249
# 21  74            Asthma  D001249
# 22  191           Asthma  D001249
# 23  0             Asthma  D001249
# 24  0             Asthma  D001249
#
#                                                                          consents
# 0   [DS-LD-IRB-COL]
# 1   [DS-ASTHMA-IRB-COL]
# 2   [DS-ASTHMA-IRB-COL]
# 3   [DS-ASTHMA-IRB-COL]
# 4   [DS-ASTHMA-IRB-COL]
# 5   [DS-ASTHMA-IRB-COL]
# 6   [DS-ASTHMA-GSO]
# 7   [NRUP, HMB-COL]
# 8   [DS-ASTHMA-IRB-COL]
# 9   [GRU]
# 10  [GRU]
# 11  [GRU]
# 12  [GRU]
# 13  [NRUP, DS-ASTHMA-IRB-MDS-RD]
# 14  [NRUP, GRU-IRB]
# 15  [DS-LD-IRB-COL]
# 16  [NRUP, GRU-IRB-COL]
# 17  [NRUP, GRU-IRB, HMB, DS-LD, HMB-IRB-NPU, DS-FDO-IRB-NPU, HMB-IRB, DS-FDO-IRB]
# 18  [GRU-NPU]
# 19  [DS-ASTHMA-IRB-PUB-NPU-MDS-GSO-RD]
# 20  [NRUP, DS-AAR-IRB]
# 21  [GRU]
# 22  [GRU]
# 23  [Analysis]
# 24  [Analysis]

# %% [markdown]
# ## Step 7 - Query for studies sponsored by a particular NIH Institute
#
# We can query on the sponsor parameter to find studies for a given NIH institute.

# %%
ic_studies = mf.run_query("ResearchStudy?sponsor=NIA")
# Out:
# Total  Resources: 39
# Total  Bytes: 804259
# Time elapsed 3.0077 seconds

# %%
studies_to_df(ic_studies)
# Out:
#            id  \
# 0   phs002610
# 1   phs002411
# 2   phs002361
# 3   phs002202
# 4   phs000397
# 5   phs001916
# 6   phs001963
# 7   phs001956
# 8   phs001808
# 9   phs001779
# 10  phs000786
# 11  phs000674
# 12  phs000788
# 13  phs001470
# 14  phs001462
# 15  phs001354
# 16  phs001353
# 17  phs001301
# 18  phs001302
# 19  phs001300
# 20  phs001209
# 21  phs000572
# 22  phs001157
# 23  phs000249
# 24  phs000745
# 25  phs000313
# 26  phs000726
# 27  phs000428
# 28  phs000215
# 29  phs000584
# 30  phs000496
# 31  phs000168
# 32  phs000451
# 33  phs000378
# 34  phs000372
# 35  phs000338
# 36  phs000138
# 37  phs000169
# 38  phs000160
#
#                                                                                                                                                                     title  \
# 0   Maintenance of Genome Sequence Integrity in Long- and Short-lived Rodent Species
# 1   Genome Instability in Mammary Cells of Pathogenic BRCA1/2 Mutation Carriers
# 2   Genomics and Epigenomics of the Elderly Response to Pneumococcal Vaccines
# 3   A New High-Throughput Sequencing-Based Technology to Study Heterochromatin Structure
# 4   NIA Long Life Family Study (LLFS)
# 5   Pilot Sequencing Study of Peripheral Blood Mononuclear Cells in Human Aging
# 6   DEMENTIA-SEQ: WGS in Lewy Body Dementia and Frontotemporal Dementia
# 7   Genome Instability in Liver Stem and Mature Cells
# 8   Landscape of Somatic Mutations in B Lymphocytes Across Human Lifespan
# 9   CIDR-NIA Whole Exome Analysis of Ehlers-Danlos Syndrome
# 10  RPGEH WGS Pilot Study
# 11  Resource for Genetic Epidemiology Research on Aging (GERA)
# 12  Research Program on Genes, Environment and Health (RPGEH)
# 13  Study of Women&#39;s Health Across the Nation (SWAN) Repository
# 14  NABEC NeuroChip Genotyping
# 15  NABEC Total RNA Sequencing of Human Cerebral Frontal Cortex
# 16  NABEC mRNA Sequencing of Human Cerebral Frontal Cortex
# 17  NABEC Exome Sequencing of Human Cerebral Frontal Cortex
# 18  NABEC CAGE Sequencing of Human Cerebral Frontal Cortex
# 19  NABEC: North American Brain Expression Consortium
# 20  MIDCIRS Reveals Antibody Diversification in Young Children with Malaria
# 21  Alzheimer&#39;s Disease Sequencing Project (ADSP)
# 22  Wisconsin Longitudinal Study on Aging
# 23  NABEC: Genome-Wide Genotyping
# 24  RNAseq analysis of posterior cingulate astrocytes in Alzheimer&#39;s disease
# 25  SardiNIA Medical Sequencing Discovery Project
# 26  Genome-Wide Association Study of Myasthenia Gravis
# 27  Health and Retirement Study (HRS)
# 28  Genome-Wide Association Analysis of Biomarkers in the InCHIANTI and BLSA
# 29  The Longevity Genes Project
# 30  Columbia University Study of Caribbean Hispanics and Late Onset Alzheimer&#39;s disease
# 31  NIA - Late Onset Alzheimer&#39;s Disease and National Cell Repository for Alzheimer&#39;s Disease Family Study: Genome-Wide Association Study for Susceptibility Loci
# 32  NHLBI and NIA The New England Centenarian Study (NECS)
# 33  Indianapolis-Ibadan, Nigeria Comparative Epidemiological Study of Dementia
# 34  ADGC Genome Wide Association Study
# 35  National Institute on Aging (NIA) SardiNIA Study
# 36  GWAS for Genetic Determinants of Bone Fragility
# 37  Whole Genome Association Study of Visceral Adiposity in the HABC Study
# 38  Genetics Consortium for Late Onset of Alzheimer&#39;s Disease (LOAD CIDR Project)
#
#     num_subjects                               focus focus_mesh  \
# 0   2             Longevity                           D008136
# 1   16
# 2   2
# 3   2             Healthy Volunteers                  D064368
# 4   4997          Longevity                           D008136
# 5   20            Healthy Aging
# 6   6907          Lewy Body Disease                   D020961
# 7   15
# 8   14            Aging                               D000375
# 9   153           Ehlers-Danlos syndrome type 3       C0268337
# 10  4
# 11  78419         Aging                               D000375
# 12  78423         Aging                               D000375
# 13  1463          Menopause                           D008593
# 14  270           Molecular Probe Techniques          D015336
# 15  276           Healthy Volunteers                  D064368
# 16  69            Healthy Volunteers                  D064368
# 17  343
# 18  142
# 19  432           Gene Expression Profiling           D020869
# 20  22            Malaria                             D008288
# 21  15630         Alzheimer Disease                   D000544
# 22  9027
# 23  382           Healthy Volunteers                  D064368
# 24  20            Alzheimer Disease                   D000544
# 25  2105          Cardiovascular Diseases             D002318
# 26  972           Myasthenia Gravis                   D009157
# 27  15620         Aging                               D000375
# 28  0             Nutritional and Metabolic Diseases  D009750
# 29  2140          Longevity                           D008136
# 30  3139          Alzheimer Disease                   D000544
# 31  5220          Alzheimer Disease                   D000544
# 32  2             Aged, 80 and over                   D000369
# 33  1251          Alzheimer Disease                   D000544
# 34  6065          Alzheimer Disease                   D000544
# 35  0             Cardiovascular Diseases             D002318
# 36  1493          Osteoporosis                        D010024
# 37  2802          Obesity                             D009765
# 38  2398          Alzheimer Disease                   D000544
#
#                                                                         consents
# 0   [GRU]
# 1   [DS-BRCA-PUB-NPU]
# 2   [GRU]
# 3   [GRU]
# 4   [NRUP, GRU-IRB, GRU-IRB-NPU, DS-LARHC-IRB-NPU]
# 5   [GRU-IRB]
# 6   [GRU]
# 7   [HMB-PUB-NPU]
# 8   [DS-AGR1-NPU]
# 9   [NRUP, DS-HCT-IRB-COL-GSO-RD]
# 10  [HMB-IRB-NPU]
# 11  [HMB-IRB-NPU]
# 12  [NRUP, HMB-IRB-NPU]
# 13  [NRUP, HMB-IRB-NPU]
# 14  [GRU]
# 15  [GRU]
# 16  [GRU]
# 17  [GRU]
# 18  [GRU]
# 19  [GRU]
# 20  [GRU]
# 21  [HMB-IRB, HMB-IRB-NPU, DS-ALZ-IRB, DS-ALZ-IRB-NPU, DS-ND-IRB, DS-ND-IRB-NPU]
# 22  [NRUP, GRU]
# 23  [GRU]
# 24  [GRU]
# 25  [NRUP, GRU-IRB]
# 26  [GRU-IRB]
# 27  [NRUP, NPR]
# 28  []
# 29  [NRUP, GRU]
# 30  [NRUP, GRU-IRB]
# 31  [NRUP, GRU, NPU, DS-ALZ, DS-ALZ-NPU]
# 32  [GRU]
# 33  [NRUP, GRU-IRB]
# 34  [ADR]
# 35  [Genotype_Analysis]
# 36  [NRUP, GRU]
# 37  [NRUP, GRU]
# 38  [NRU, GRU, NPU, ALZ, ALZ_NPU]

# %% [markdown]
# ## Step 8 - Query for studies with a particular disease focus
#
# We can query on the focus parameter to find studies which were focussed on a particular disease. The disease codes used are Mesh terms.

# %%
az_studies = mf.run_query("ResearchStudy?focus=D000544")
studies_to_df(az_studies)
# Out:
# Total  Resources: 9
# Total  Bytes: 348787
# Time elapsed 0.2566 seconds
#           id  \
# 0  phs000572
# 1  phs000745
# 2  phs000727
# 3  phs000496
# 4  phs000168
# 5  phs000378
# 6  phs000372
# 7  phs000219
# 8  phs000160
#
#                                                                                                                                                                    title  \
# 0  Alzheimer&#39;s Disease Sequencing Project (ADSP)
# 1  RNAseq analysis of posterior cingulate astrocytes in Alzheimer&#39;s disease
# 2  miRNA Profiles in Serum and CSF of Parkinson&#39;s and Alzheimer&#39;s Patients
# 3  Columbia University Study of Caribbean Hispanics and Late Onset Alzheimer&#39;s disease
# 4  NIA - Late Onset Alzheimer&#39;s Disease and National Cell Repository for Alzheimer&#39;s Disease Family Study: Genome-Wide Association Study for Susceptibility Loci
# 5  Indianapolis-Ibadan, Nigeria Comparative Epidemiological Study of Dementia
# 6  ADGC Genome Wide Association Study
# 7  GenADA/LONG/Imaging (Genetic Alzheimer&#39;s Disease Associations)
# 8  Genetics Consortium for Late Onset of Alzheimer&#39;s Disease (LOAD CIDR Project)
#
#    num_subjects              focus focus_mesh  \
# 0  15630         Alzheimer Disease  D000544
# 1  20            Alzheimer Disease  D000544
# 2  211           Alzheimer Disease  D000544
# 3  3139          Alzheimer Disease  D000544
# 4  5220          Alzheimer Disease  D000544
# 5  1251          Alzheimer Disease  D000544
# 6  6065          Alzheimer Disease  D000544
# 7  1718          Alzheimer Disease  D000544
# 8  2398          Alzheimer Disease  D000544
#
#                                                                        consents
# 0  [HMB-IRB, HMB-IRB-NPU, DS-ALZ-IRB, DS-ALZ-IRB-NPU, DS-ND-IRB, DS-ND-IRB-NPU]
# 1  [GRU]
# 2  [GRU]
# 3  [NRUP, GRU-IRB]
# 4  [NRUP, GRU, NPU, DS-ALZ, DS-ALZ-NPU]
# 5  [NRUP, GRU-IRB]
# 6  [ADR]
# 7  [GBA]
# 8  [NRU, GRU, NPU, ALZ, ALZ_NPU]
